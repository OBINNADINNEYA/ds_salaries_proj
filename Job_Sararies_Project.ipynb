# %%
import pandas as pd

# %%
df = pd.read_csv('data scientist_1.csv')
df2 = pd.read_csv('data scientist_2.csv')

# %%
df
# Out:
#      Unnamed: 0                          company  \
# 0             0        Daiichi Sankyo, Inc.\n4.1
# 1             1            Northrop Grumman\n4.0
# 2             2                     Confidential
# 3             3             Near-Miss Management
# 4             4    ENGIE North America Inc.\n3.9
# ..          ...                              ...
# 295         295                  OneMagnify\n4.4
# 296         296  Liberty Personnel Services\n4.5
# 297         297                       Pragmatics
# 298         298                 VirginPulse\n3.4
# 299         299                      Kforce\n4.0
#
#                                              job title           location  \
# 0              Senior Analyst, Statistical Programming  Basking Ridge, NJ
# 1                             Principal Data Scientist     Clearfield, UT
# 2            Applied Scientist, Generative AI Research     El Segundo, CA
# 3    Senior Data Scientist - Accepting Recent PhD G...   Philadelphia, PA
# ...

# %%
df2
# Out:
#      Unnamed: 0                     company  \
# 0             0   Daiichi Sankyo, Inc.\n4.1
# 1             1   Daiichi Sankyo, Inc.\n4.1
# 2             2                Epsilon\n3.9
# 3             3  Signal Systems Corporation
# 4             4                   CACI\n3.9
# ..          ...                         ...
# 445         445          DCI Solutions\n3.7
# 446         446      Tek Intelligence, Inc.
# 447         447     Old Republic Title\n3.5
# 448         448                   ON1, inc.
# 449         449     Sysdata Consulting, Inc
#
#                                              job title             location  \
# 0              Senior Analyst, Statistical Programming    Basking Ridge, NJ
# 1    Director, Statistical Programming (Technology ...    Basking Ridge, NJ
# 2    PhD Director, Data Science R&D (Decision Scien...          Chicago, IL
# 3    Acoustic Signal Processing Engineer - Data Sci...     Millersville, MD
# ...
